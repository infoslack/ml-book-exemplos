# %% [markdown]
# ## Prática
#
# Este notebook serve para você praticar o que viu no livro.
#
# Pode haver mais de uma maneira diferente de completar um exercício.
#
# Os exercícios são baseados no conteúdo do livro.
#
# Para mais referências e recursos, fica a sugestão de consultar a [documentação da Matplotlib.](https://matplotlib.org/stable/users/index.html)

# %%
# Importe o módulo pyplot da matplotlib como "plt"

# %%
# Crie um plot simples usando plt.plot()

# %%
# Plot uma única lista Python

# %%
# Crie duas listas, uma chamada x, outra chamada y cada uma com 5 números
# Plote as listas x & y

# %%
# Crie um plot usando plt.subplots()

# %%
# Crie um plot usando plt.subplots() e adicione as listas x & y nos axes

# %%
# Import o NumPy
# Crie um array de 100 números (distribuídos normalmente) entre 0 e 100
# salvando o array em uma variável x

# %%
# Crie um plot usando plt.subplots() e plot x e x² (squared)

# %%
# Crie uma scatter plot de X e X exponencial (np.exp(X))

# %%
# Crie um dicionário Python de 3 produtos
# as chaves do dicionário podem ser nomes de alimentos
# e os valores podem ser preços

# %%
# Crie um gráfio de barras onde x-axis recebe como valor as chaves do dicionário
# e y-axis recebe os valores do dicionário

# %%
# Adicione um título, xlabel e ylabel ao último plot criado

# %%
# Faça o mesmo plot, dessa vez com barras horizontais

# %%
# Crie um array de 1000 números aleatórios distribuídos normalmente
# plote um histograma com esse array

# %%
# Importe o pandas como pd
# crie um dataframe importando o arquivo "heart-disease.csv"
# salve o dataframe em uma variável "df"

# %% [markdown]
# ![oo-plot-3.png](data:image/png;base64,...)

# %%
# O próximo desafio é replicar o gráfico acima da maneira que achar melhor

# Dica de workflow

# Criar um filtro com pacientes com mais de 50 anos

# Criar o plot

# Plotar os dados

# Personalize o plot

# Adicionar uma linha média
